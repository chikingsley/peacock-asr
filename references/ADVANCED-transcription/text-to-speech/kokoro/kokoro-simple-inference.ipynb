# %% [markdown]
# # Kokoro Simple Inference
#
# Built by Trelis.com from [the original repo](https://github.com/hexgrad/kokoro).

# %%
# !uv pip install kokoro-onnx soundfile
# Out:
# Audited 2 packages in 74ms

# %%
# !mkdir -p models
# !wget https://github.com/thewh1teagle/kokoro-onnx/releases/download/model-files-v1.0/kokoro-v1.0.onnx -O ./models/kokoro-v1.0.onnx
# !wget https://github.com/thewh1teagle/kokoro-onnx/releases/download/model-files-v1.0/voices-v1.0.bin -O ./models/voices-v1.0.bin
# Out:
# --2025-11-21 11:58:42--  https://github.com/thewh1teagle/kokoro-onnx/releases/download/model-files-v1.0/kokoro-v1.0.onnx
# Resolving github.com (github.com)... 4.208.26.197
# Connecting to github.com (github.com)|4.208.26.197|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import soundfile as sf
from kokoro_onnx import Kokoro

kokoro = Kokoro("models/kokoro-v1.0.onnx", "models/voices-v1.0.bin")
samples, sr = kokoro.create(
    "Hello from Kokoro, let's next move to setting up a server!",
    voice="bm_george",
    speed=1.0,
    # lang="en_us",
)
sf.write("audio.wav", samples, sr)
